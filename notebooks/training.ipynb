# %%
import os 

import pybullet_envs

from stable_baselines3 import PPO
from stable_baselines3.common.cmd_util import make_vec_env
from stable_baselines3.common.vec_env import VecNormalize
# Out:
# /Users/redtachyon/projects/stable-baselines3/stable_baselines3/common/cmd_util.py:5: FutureWarning: Module ``common.cmd_util`` has been renamed to ``common.env_util`` and will be removed in the future.
#   warnings.warn(

# %%
env = make_vec_env("HalfCheetahBulletEnv-v0", n_envs=1)

env = VecNormalize(env, norm_obs=True, norm_reward=True, clip_obs=10.)
# Out:
# /Users/redtachyon/anaconda3/envs/beta/lib/python3.9/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log="ppo_working", gamma=0.99, gae_lambda=0.95)#, alpha=99*2., beta=1*2.)
model.learn(total_timesteps=1000000, tb_log_name="ppo_gamma")
# Out:
# Using cpu device
# Logging to ppo_working/ppo_gamma_1
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | -1.39e+03 |
# | time/              |           |
# |    fps             | 785       |
# |    iterations      | 1         |
# |    time_elapsed    | 2         |
# |    total_timesteps | 2048      |
# ----------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -1.38e+03   |
# | time/                   |             |
# |    fps                  | 628         |
# |    iterations           | 2           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.015950717 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# ...

# %%
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log="ppo_working", gamma=0.99, gae_lambda=0.95, alpha=99*2., beta=1*2.)
model.learn(total_timesteps=1000000, tb_log_name="ppo_beta")
# Out:
# Using cpu device
# Logging to ppo_working/ppo_beta_3
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | -1.16e+03 |
# | time/              |           |
# |    fps             | 834       |
# |    iterations      | 1         |
# |    time_elapsed    | 2         |
# |    total_timesteps | 2048      |
# ----------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -1.26e+03   |
# | time/                   |             |
# |    fps                  | 678         |
# |    iterations           | 2           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.017821215 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# ...

# %%
import pdb; pdb.pm()
# Out:
# > <__array_function__ internals>(5)concatenate()
# ipdb>  dones
# *** NameError: name 'dones' is not defined
# ipdb>  l
# ipdb>
# ipdb>  1
# 1
# ipdb>  a
# args = ((array([[0.],
#        [0.],
#        [0.],
#        ...,
#        [0.],
#        [0.],
#        [0.]], dtype=float32), array([False])),)
# kwargs = {}
# ipdb>  b
# ipdb>
# ipdb>  q
